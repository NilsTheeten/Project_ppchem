# %%
import sys

# Manually set the path to the directory containing hydroponics.py
src_path = "../src"  # Change this to the actual path

sys.path.append(src_path)
from hydroponics.Basic_functions import *
from hydroponics.Solutions_Solubility import plot_graph

# %%
solution = {"Na+": 0.1, "Cl-": 0.1, "Ca++": 0.1, "SO4--": 0.1, "Mg++": 0.1, "K+": 0.1, "HCO3-": 0.1}
plant = {"Na+": 0.1, "Cl-": 0.1, "Ca++": 0.1, "SO4--": 0.1, "Mg++": 0.1, "K+": 0.1, "HCO3-": 0.1}
growth_time = 30

plot_graph(solution, "ion", plant, growth_time,volume =1,ions_of_interest=["Na+","Cl-","Ca++"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 plant = {"Na+": 0.1, "Cl-": 0.1, "Ca++": 0.1, "SO4--": 0.1, "Mg++": 0.1, "K+": 0.1, "HCO3-": 0.1}
#       3 growth_time = 30
# ----> 5 plot_graph(solution, "ion", plant, growth_time,volume =1,ions_of_interest=["Na+","Cl-","Ca++"])
#
# File c:\Users\nilst\Documents\EPFL\BA_4\ppchem\Project\Project_ppchem\tests\../src\hydroponics\Solutions_Solubility.py:254, in plot_graph(solution, input_type, plant, growth_time, volume, ions_of_interest)
#     252 #Plot the data for the ions of interest
#     253 i = 0 #handle the colors
# --> 254 data = data4graph(initial_ion_solution, volume, plant, growth_time)
#     255 for ion in initial_ion_solution.keys():
#     256     if ion in ions_of_interest or ions_of_interest == "all":
#
# File c:\Users\nilst\Documents\EPFL\BA_4\ppchem\Project\Project_ppchem\tests\../src\hydroponics\Solutions_Solubility.py:198, in data4graph(solution, volume, plant, growth_time)
#     196 for i in range(1,growth_time+1):
#     197         if check_supply_elements(solution, daily_need_plant):
# --> 198             solution = update_sol(solution, daily_need_plant, volume)
#     199             data[0].append(i)
#     200             data[1].append(solution.copy())
#
# File c:\Users\nilst\Documents\EPFL\BA_4\ppchem\Project\Project_ppchem\tests\../src\hydroponics\Solutions_Solubility.py:163, in update_sol(ions_solution, plant, volume)
#     160     else:
#     161         ions_solution[ion] -= volume_plant[ion]
# --> 163 if check_solubility(ions_solution, input_type="ion"):
#     164     return ions_solution
#     165 else:
#
# File c:\Users\nilst\Documents\EPFL\BA_4\ppchem\Project\Project_ppchem\tests\../src\hydroponics\Solutions_Solubility.py:47, in check_solubility(salts_dict, input_type, output_type)
#      45     ions = salt2ions(salts_dict_molar, volume = 1)
#      46 if input_type == "ion":
# ---> 47     ions = {ion: concentration / get_molar_mass(ion) for ion, concentration in salts_dict.items()}
#      49 #Initialize variables
#      50 soluble = True
#
# File c:\Users\nilst\Documents\EPFL\BA_4\ppchem\Project\Project_ppchem\tests\../src\hydroponics\Solutions_Solubility.py:47, in <dictcomp>(.0)
#      45     ions = salt2ions(salts_dict_molar, volume = 1)
#      46 if input_type == "ion":
# ---> 47     ions = {ion: concentration / get_molar_mass(ion) for ion, concentration in salts_dict.items()}
#      49 #Initialize variables
#      50 soluble = True
#
# File c:\Users\nilst\Documents\EPFL\BA_4\ppchem\Project\Project_ppchem\tests\../src\hydroponics\Basic_functions.py:223, in get_molar_mass(salt)
#     220         M += molar(substing)
#     221         salt = salt[:left] + salt[right+1:]
# --> 223 total_molar_mass = M + molar(salt)
#     224 return total_molar_mass
#
# File c:\Users\nilst\Documents\EPFL\BA_4\ppchem\Project\Project_ppchem\tests\../src\hydroponics\Basic_functions.py:180, in get_molar_mass.<locals>.molar(molecule)
#     178     current_count = 1
#     179     i+=2
# --> 180     molar_mass += get_atom_mass(current_element)*int(current_count)
#     181     continue
#     182 if molecule[i].isupper() and molecule[i+1].isupper():
#
# File c:\Users\nilst\Documents\EPFL\BA_4\ppchem\Project\Project_ppchem\tests\../src\hydroponics\Basic_functions.py:90, in get_atom_mass(atom_name)
#      88 # Define the name of the CSV file
#      89 csv_file = "data/molar_mass.csv" #Check path to CSV file
# ---> 90 with open(csv_file, mode='r') as file:
#      91     reader = csv.DictReader(file)
#      92     for row in reader:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/molar_mass.csv'
